# %%
import pandas as pd

# %%
sozluk = {"Kategori": ["Giyim","Giyim", "Ayakkabı","Aksesuar","Ayakkabı","Giyim","Aksesuar","Aksesuar","Ayakkabı","Giyim"],


  "Ürün" : ["Kazak","T-shirt","Sandalet","Küpe","Spor Ayakkabı","Pantolon","Kolye","Yüzük","Çizme","Ceket"],


"Fiyat" : [300,180,450,50,700,400,150,80,850,900]}

# %%
data = pd.DataFrame(sozluk)

# %%
# 2.indexte bulunan kategori bulunur. (Sadece kategori bilgisi) 
pd.DataFrame(sozluk, columns = ["Kategori"])
# Out:
#    Kategori
# 0     Giyim
# 1     Giyim
# 2  Ayakkabı
# 3  Aksesuar
# 4  Ayakkabı
# 5     Giyim
# 6  Aksesuar
# 7  Aksesuar
# 8  Ayakkabı
# 9     Giyim

# %%
# 2. indexte bulunan ürün bulunur. (Sadece ürün bilgisi) 

pd.DataFrame(sozluk, columns = ["Ürün"])
# Out:
#             Ürün
# 0          Kazak
# 1        T-shirt
# 2       Sandalet
# 3           Küpe
# 4  Spor Ayakkabı
# 5       Pantolon
# 6          Kolye
# 7          Yüzük
# 8          Çizme
# 9          Ceket

# %%
#4.indexten 9.indexe kadar olan veriler bulunur. (Kategori,ürün,fiyat bilgisi beraber) 

data.iloc[4:10, :]
# Out:
#    Kategori           Ürün  Fiyat
# 4  Ayakkabı  Spor Ayakkabı    700
# 5     Giyim       Pantolon    400
# 6  Aksesuar          Kolye    150
# 7  Aksesuar          Yüzük     80
# 8  Ayakkabı          Çizme    850
# 9     Giyim          Ceket    900

# %%
#1.indexten 6.indexe kadar olan ürünler bulunur. (Sadece ürün bilgisi) 
data.iloc[1:7,1]
# Out:
# 1          T-shirt
# 2         Sandalet
# 3             Küpe
# 4    Spor Ayakkabı
# 5         Pantolon
# 6            Kolye
# Name: Ürün, dtype: object

# %%
# Giyim kategorisinde bulunan ürünler gösterilir. 
data
# Out:
#    Kategori           Ürün  Fiyat
# 0     Giyim          Kazak    300
# 1     Giyim        T-shirt    180
# 2  Ayakkabı       Sandalet    450
# 3  Aksesuar           Küpe     50
# 4  Ayakkabı  Spor Ayakkabı    700
# 5     Giyim       Pantolon    400
# 6  Aksesuar          Kolye    150
# 7  Aksesuar          Yüzük     80
# 8  Ayakkabı          Çizme    850
# 9     Giyim          Ceket    900

# %%
# Giyim kategorisinde bulunan ürünler gösterilir. 
data[data["Kategori"] == "Giyim"]
# Out:
#   Kategori      Ürün  Fiyat
# 0    Giyim     Kazak    300
# 1    Giyim   T-shirt    180
# 5    Giyim  Pantolon    400
# 9    Giyim     Ceket    900

# %%
# Ayakkabı kategorisinde bulunan ürünler gösterilir. 
data[data["Kategori"] == "Ayakkabı"]
# Out:
#    Kategori           Ürün  Fiyat
# 2  Ayakkabı       Sandalet    450
# 4  Ayakkabı  Spor Ayakkabı    700
# 8  Ayakkabı          Çizme    850

# %%
#Aksesuar kategorisinde bulunan ürünler gösterilir. 
data[data["Kategori"] == "Aksesuar"]
# Out:
#    Kategori   Ürün  Fiyat
# 3  Aksesuar   Küpe     50
# 6  Aksesuar  Kolye    150
# 7  Aksesuar  Yüzük     80

# %%
data
# Out:
#    Kategori           Ürün  Fiyat
# 0     Giyim          Kazak    300
# 1     Giyim        T-shirt    180
# 2  Ayakkabı       Sandalet    450
# 3  Aksesuar           Küpe     50
# 4  Ayakkabı  Spor Ayakkabı    700
# 5     Giyim       Pantolon    400
# 6  Aksesuar          Kolye    150
# 7  Aksesuar          Yüzük     80
# 8  Ayakkabı          Çizme    850
# 9     Giyim          Ceket    900

# %%
#Giyim kategorisinde fiyatı 300'den fazla olan ürünler gösterilir.
giyim=data[data["Kategori"] == "Giyim"] 
giyim[giyim['Fiyat'] > 300]
# Out:
#   Kategori      Ürün  Fiyat
# 5    Giyim  Pantolon    400
# 9    Giyim     Ceket    900

# %%
#Ayakkabı kategorisinde fiyatı 600'den az olan ürünler gösterilir.
ayakkabi=data[data["Kategori"] == "Ayakkabı"]
ayakkabi[ayakkabi['Fiyat']<600]
# Out:
#    Kategori      Ürün  Fiyat
# 2  Ayakkabı  Sandalet    450

# %%
# Aksesuar kategorisinde fiyatı 100'den fazla olan aksesuar gösterilir. 
aksesuar=data[data["Kategori"] == "Aksesuar"]
aksesuar[aksesuar['Fiyat']>100]
# Out:
#    Kategori   Ürün  Fiyat
# 6  Aksesuar  Kolye    150
